# %% [markdown]
# <a href="https://colab.research.google.com/github/Estefany1387/NFL_GibData/blob/main/Graficas_proyecto_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
link = 'https://drive.google.com/file/d/19dqv2hWHkm-ow-OoViKu8_7MjRCptLkC/view?usp=sharing'
import pandas as pd

# to get the id part of the file
id = link.split("/")[-2]

downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('Jornadas2.csv')

Jornadas = pd.read_csv('Jornadas2.csv')
print(Jornadas)
# Out:
#            gameId  playId  jugador of  jerseyNumber playDirection      x  \
# 0      2021100400     485      D.Carr             4          left  82.32
# 1      2021100400     485      D.Carr             4          left  82.33
# 2      2021100400     485      D.Carr             4          left  82.33
# 3      2021100400     485      D.Carr             4          left  82.33
# 4      2021100400     485      D.Carr             4          left  82.33
# ...           ...     ...         ...           ...           ...    ...
# 18187  2021102407    3161  B. Edwards            89          left  31.98
# 18188  2021102407    3161  B. Edwards            89          left  31.75
# 18189  2021102407    3161  B. Edwards            89          left  31.57
# 18190  2021102407    3161  B. Edwards            89          left  31.43
# 18191  2021102407    3161  B. Edwards            89          left  31.33
#
#            y     s     a   dis       o     dir         event
# ...

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
link = 'https://drive.google.com/file/d/1ULX-9VP72TGxAXps9Ibhhg1y-Y1zA5ZI/view?usp=sharing'
import pandas as pd

# to get the id part of the file
id = link.split("/")[-2]

downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('Jugada.csv')

Jugadas = pd.read_csv('Jugada.csv')
print(Jugadas)
# Out:
#          gameId  jugada                                    playDescription  \
# 0    2021100400     485  (6:38) (Shotgun) D.Carr pass incomplete short ...
# 1    2021100400     644  (5:24) D.Carr pass incomplete short middle to ...
# 2    2021100400     666  (5:21) (Shotgun) D.Carr pass short right to H....
# 3    2021100400     707  (4:35) (Shotgun) D.Carr sacked at LV 18 for -9...
# 4    2021100400     921  (1:59) (Shotgun) D.Carr sacked at LV 26 for -1...
# ..          ...     ...                                                ...
# 97   2021102407    2288  (9:01) (Shotgun) D.Carr pass short left to J.R...
# 98   2021102407    2339  (8:05) (Shotgun) D.Carr pass short middle to B...
# 99   2021102407    2406  (6:44) (Shotgun) D.Carr pass short right to H....
# 100  2021102407    3074  (10:59) D.Carr pass deep left to A.Ingold to P...
# 101  2021102407    3161  (8:05) (Shotgun) D.Carr pass short left to J.R...
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
#libreria matpyplot
from matplotlib import pyplot as plt
sns.set_style('darkgrid')

# %%
Jugadas.head(5)
# Out:
#        gameId  jugada                                    playDescription  \
# 0  2021100400     485  (6:38) (Shotgun) D.Carr pass incomplete short ...
# 1  2021100400     644  (5:24) D.Carr pass incomplete short middle to ...
# 2  2021100400     666  (5:21) (Shotgun) D.Carr pass short right to H....
# 3  2021100400     707  (4:35) (Shotgun) D.Carr sacked at LV 18 for -9...
# 4  2021100400     921  (1:59) (Shotgun) D.Carr sacked at LV 26 for -1...
#
#    quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0        1     3          7             LV           LAC           LV
# 1        1     1         10             LV           LAC           LV
# 2        1     2         10             LV           LAC           LV
# 3        1     3          6             LV           LAC           LV
# 4        1     1         15             LV           LAC           LV
#
#    yardlineNumber  preSnapHomeScore  preSnapVisitorScore passResult  \
# ...

# %%
Jornadas.head(5)
# Out:
#        gameId  playId jugador of  jerseyNumber playDirection      x      y  \
# 0  2021100400     485     D.Carr             4          left  82.32  29.61
# 1  2021100400     485     D.Carr             4          left  82.33  29.60
# 2  2021100400     485     D.Carr             4          left  82.33  29.60
# 3  2021100400     485     D.Carr             4          left  82.33  29.61
# 4  2021100400     485     D.Carr             4          left  82.33  29.61
#
#       s     a   dis       o    dir event
# 0  0.01  0.02  0.00  263.87   5.94  None
# 1  0.01  0.01  0.02  262.60  23.27  None
# 2  0.01  0.01  0.00  262.60  19.42  None
# 3  0.01  0.01  0.01  262.60  19.56  None
# 4  0.01  0.01  0.01  261.80  16.85  None

# %%
sns.barplot(Jornadas , y='jugador of', x= 'dis')
plt.title('Distancia recorrida por jugador')
# Out:
# Text(0.5, 1.0, 'Distancia recorrida por jugador')

# %%
sns.barplot(Jornadas , y='jugador of', x= 'y')
plt.title('Distancia recorrida por jugador')
# Out:
# Text(0.5, 1.0, 'Distancia recorrida por jugador')

# %%
sns.barplot(Jornadas , y='jugador of', x= 'a')
plt.title("ACELERACIÓN PROMEDIO POR JUGADOR")
plt.ylabel('Jugador')
plt.xlabel('Aceleración yardas/s^2')
plt.show()

# %%
sns.barplot(Jornadas , y='jugador of', x= 's')
# Out:
# <Axes: xlabel='s', ylabel='jugador of'>

# %%
plt.plot(Jugadas['passResult'])

# %%
plt.boxplot([Jornadas["x"], Jornadas["y"]],vert=False,patch_artist=True, labels=["x","y"])
plt.title('TIPO DE MOVIMIENTO DEL JUGADOR EN EL CAMPO')
plt.xlabel('Sobre el eje de la X')
plt.ylabel('Sobre el eje de la Y')
plt.show()

# %%
sns.boxplot(y="passResult" , x="quarter", data=Jugadas )
#Personalizar el grafico


plt.title('TIPO DE PASE POR QUARTER')
plt.xlabel('Tipo de pase')
plt.ylabel('Quarter')
plt.show()

# %%
Jugadas.dropBackType.value_counts().plot(kind="pie",autopct='%.2f%%')
# Out:
# <Axes: ylabel='dropBackType'>

# %%
Jugadas.offenseFormation.value_counts().plot(kind="pie", autopct='%.2f%%' )
plt.title("TIPO DE FORMACIÓN")
plt.xlabel('Formación')
plt.ylabel('Total')
plt.show()

# %%
Jugadas.pff_passCoverageType.value_counts().plot(kind="bar")
plt.title("Formación ofensiva")
# Out:
# Text(0.5, 1.0, 'Formación ofensiva')

# %%
Jugadas.pff_passCoverageType.value_counts().plot(kind="bar", xlabel="Covertura")
plt.ylabel("Number")
plt.title("Formación ofensiva")
# Out:
# Text(0.5, 1.0, 'Formación ofensiva')

# %%
Jornadas.event.value_counts().plot(kind="pie")
plt.title("Formación ofensiva")
# Out:
# Text(0.5, 1.0, 'Formación ofensiva')

# %%
y=Jugadas.groupby(['dropBackType', 'offenseFormation']).offenseFormation.count().unstack()
print(y)
# Out:
# offenseFormation        EMPTY  I_FORM  SHOTGUN  SINGLEBACK
# dropBackType
# DESIGNED_ROLLOUT_RIGHT    NaN     1.0      1.0         3.0
# SCRAMBLE                  1.0     1.0      7.0         1.0
# TRADITIONAL              12.0     4.0     52.0        12.0

# %%
Jugadas.groupby(['dropBackType', 'offenseFormation']).offenseFormation.count().unstack().plot(kind="bar")
# Out:
# <Axes: xlabel='dropBackType'>

# %%
ace=Jornadas.groupby('jugador of').a.mean().round(2)
print(ace)
# Out:
# jugador of
# B. Edwards    2.42
# D.Carr        1.65
# H. Renfrow    2.32
# H. Ruggs      2.70
# J.Jacobs      1.91
# K. Drake      2.05
# Name: a, dtype: float64

# %%
Jornadas.groupby('jugador of').a.mean().round(2).plot(kind="bar")
plt.title("TIPO DE FORMACIÓN")
plt.xlabel('Formación')
plt.ylabel('Total')
plt.show()

# %%
b=Jornadas.groupby('jugador of').s.mean().round(2)
print(b)
# Out:
# jugador of
# B. Edwards    3.85
# D.Carr        1.80
# H. Renfrow    3.38
# H. Ruggs      4.63
# J.Jacobs      2.60
# K. Drake      2.72
# Name: s, dtype: float64

# %%
Jornadas.groupby('jugador of').s.mean().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='jugador of'>

# %%
c=Jornadas.groupby('jugador of').dis.mean().round(2)
print(c)
# Out:
# jugador of
# B. Edwards    0.38
# D.Carr        0.18
# H. Renfrow    0.34
# H. Ruggs      0.46
# J.Jacobs      0.26
# K. Drake      0.27
# Name: dis, dtype: float64

# %%
f=Jornadas.groupby('jugador of').dis.count().round(2)
print(f)
# Out:
# jugador of
# B. Edwards    3638
# D.Carr        4196
# H. Renfrow    3283
# H. Ruggs      3684
# J.Jacobs      2277
# K. Drake      1114
# Name: dis, dtype: int64

# %%
Jornadas.groupby('jugador of').y.count().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='jugador of'>

# %%
Jornadas.groupby('jugador of').dis.sum().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='jugador of'>

# %%
g=Jornadas.groupby('jugador of').dis.sum().round(2)
print(g)
# Out:
# jugador of
# B. Edwards    1395.22
# D.Carr         753.19
# H. Renfrow    1103.97
# H. Ruggs      1701.73
# J.Jacobs       587.60
# K. Drake       300.20
# Name: dis, dtype: float64

# %%
i=Jornadas.groupby(['gameId', 'jugador of']).dis.sum().round(2)
print(i)
# Out:
# gameId      jugador of
# 2021100400  B. Edwards    280.35
#             D.Carr        148.75
#             H. Renfrow    198.74
#             H. Ruggs      310.51
#             J.Jacobs      169.60
#             K. Drake       38.95
# 2021101010  B. Edwards    408.96
#             D.Carr        209.07
#             H. Renfrow    381.12
#             H. Ruggs      525.54
#             J.Jacobs      168.69
#             K. Drake       94.81
# 2021101709  B. Edwards    325.47
#             D.Carr        210.67
#             H. Renfrow    257.71
#             H. Ruggs      442.22
#             J.Jacobs      148.04
#             K. Drake       69.36
# 2021102407  B. Edwards    380.44
#             D.Carr        184.70
#             H. Renfrow    266.40
#             H. Ruggs      423.46
#             J.Jacobs      101.27
#             K. Drake       97.08
# Name: dis, dtype: float64

# %%
Jornadas.groupby(['gameId', 'jugador of']).dis.sum().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='gameId,jugador of'>

# %%
Jornadas.groupby('gameId').dis.sum().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='gameId'>

# %%
Jornadas.groupby('gameId').dir.mean().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='gameId'>

# %%
Jornadas.groupby('gameId').a.mean().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='gameId'>

# %%
Jornadas.groupby('gameId').s.count().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='gameId'>

# %%
Jornadas.groupby('gameId').s.mean().round(2).plot(kind="bar")
# Out:
# <Axes: xlabel='gameId'>

# %%
a=Jugadas.groupby(['offenseFormation', 'passResult']).offenseFormation.count().unstack()
print(a)
# Out:
# passResult           C     I   IN    R    S
# offenseFormation
# EMPTY             11.0   3.0  NaN  NaN  NaN
# I_FORM             4.0   2.0  NaN  1.0  NaN
# SHOTGUN           39.0  16.0  2.0  2.0  6.0
# SINGLEBACK        11.0   4.0  NaN  NaN  1.0

# %%
Jugadas.groupby(['offenseFormation', 'passResult']).offenseFormation.count().unstack().plot(kind="bar")
plt.title("TIPO DE FORMACIÓN Y RESULTADO DE PASE")
plt.xlabel('Formación y Resultado de pase')
plt.ylabel('Total')
plt.show()

# %%
Jornadas.describe()
# Out:
#              gameId        playId  jerseyNumber             x             y  \
# count  1.819200e+04  18192.000000  18192.000000  18192.000000  18192.000000
# mean   2.021101e+09   1909.054969     28.207289     56.905356     26.681380
# std    7.221742e+02   1071.899005     31.267292     26.298522      9.583911
# min    2.021100e+09     55.000000      4.000000      0.960000      0.620000
# 25%    2.021101e+09    964.000000     11.000000     32.652500     20.507500
# 50%    2.021101e+09   1924.000000     13.000000     58.940000     26.910000
# 75%    2.021102e+09   2577.000000     28.000000     81.372500     33.140000
# max    2.021102e+09   3990.000000     89.000000    112.980000     52.500000
#
#                   s             a           dis             o           dir
# count  18192.000000  18192.000000  18192.000000  18192.000000  18192.000000
# mean       3.224604      2.195224      0.321125    178.797956    176.820429
# ...

# %%
Jugadas.describe()
# Out:
#              gameId       jugada     quarter        down   yardsToGo  \
# count  1.020000e+02   102.000000  102.000000  102.000000  102.000000
# mean   2.021101e+09  1857.323529    2.362745    1.950980    8.892157
# std    7.308153e+02  1059.333222    1.051065    0.883035    4.402760
# min    2.021100e+09    55.000000    1.000000    0.000000    0.000000
# 25%    2.021101e+09   931.750000    1.250000    1.000000    6.000000
# 50%    2.021102e+09  1783.000000    2.000000    2.000000   10.000000
# 75%    2.021102e+09  2555.500000    3.000000    3.000000   10.000000
# max    2.021102e+09  3990.000000    4.000000    4.000000   22.000000
#
#        yardlineNumber  preSnapHomeScore  preSnapVisitorScore  \
# count      102.000000        102.000000           102.000000
# mean        26.166667          7.872549             9.009804
# std         11.048125          6.954835             7.109463
# min          2.000000          0.000000             0.000000
# ...

# %%
fig, ax= plt.subplots(figsize=(15,8))
ax.plot(Jugadas['yardsToGo'])
plt.show()

# %%
Jugadas.head()
# Out:
#        gameId  jugada                                    playDescription  \
# 0  2021100400     485  (6:38) (Shotgun) D.Carr pass incomplete short ...
# 1  2021100400     644  (5:24) D.Carr pass incomplete short middle to ...
# 2  2021100400     666  (5:21) (Shotgun) D.Carr pass short right to H....
# 3  2021100400     707  (4:35) (Shotgun) D.Carr sacked at LV 18 for -9...
# 4  2021100400     921  (1:59) (Shotgun) D.Carr sacked at LV 26 for -1...
#
#    quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0        1     3          7             LV           LAC           LV
# 1        1     1         10             LV           LAC           LV
# 2        1     2         10             LV           LAC           LV
# 3        1     3          6             LV           LAC           LV
# 4        1     1         15             LV           LAC           LV
#
#    yardlineNumber  preSnapHomeScore  preSnapVisitorScore passResult  \
# ...

# %%
x=Jugadas.groupby(['quarter', 'offenseFormation']).offenseFormation.count().unstack()

print(x)
# Out:
# offenseFormation  EMPTY  I_FORM  SHOTGUN  SINGLEBACK
# quarter
# 1                   3.0     3.0     14.0         6.0
# 2                   3.0     2.0     20.0         6.0
# 3                   8.0     NaN     16.0         3.0
# 4                   NaN     2.0     15.0         1.0

# %%
Jugadas.groupby(['quarter', 'offenseFormation']).offenseFormation.count().unstack().plot(kind="bar")
plt.title("TIPO DE FORMACIÓN POR QUARTER")
plt.xlabel('Formación por quarter')
plt.ylabel('Total')
plt.show()

# %%
plt.plot(Jugadas['passResult'])

# %%
#Calcula la media, media y moda
media=Jornadas['y'].mean()
moda=Jornadas['y'].mode().values[0]
mediana=Jornadas['y'].median()

# %%
print(media)
print(moda)
print(mediana)
# Out:
# 26.68137972735268
# 23.92
# 26.91

# %%
d=Jugadas.groupby(['quarter', 'offenseFormation']).offenseFormation.count().unstack()
print(d)
# Out:
# offenseFormation  EMPTY  I_FORM  SHOTGUN  SINGLEBACK
# quarter
# 1                   3.0     3.0     14.0         6.0
# 2                   3.0     2.0     20.0         6.0
# 3                   8.0     NaN     16.0         3.0
# 4                   NaN     2.0     15.0         1.0

# %%
e=Jugadas.groupby(['gameId', 'offenseFormation']).offenseFormation.count().unstack()
print(e)
# Out:
# offenseFormation  EMPTY  I_FORM  SHOTGUN  SINGLEBACK
# gameId
# 2021100400          4.0     NaN     13.0         2.0
# 2021101010          6.0     NaN     20.0         3.0
# 2021101709          2.0     4.0     16.0         4.0
# 2021102407          2.0     3.0     16.0         7.0

# %%
Jugadas.groupby(['gameId', 'offenseFormation']).offenseFormation.count().unstack().plot(kind="bar")
plt.title("TIPO DE FORMACIÓN POR JORNADA")
plt.xlabel('JORNADA ')
plt.ylabel('TOTAL')
plt.show()
